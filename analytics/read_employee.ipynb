# %%
import pandas as pd

# %%
df = pd.read_csv("employee.csv")
df

# %%
type(df)

# %%
df

# %% [markdown]
# read first 5 lines from file

# %%
df.head(10)

# %%
# read lsat 5 rows
df.tail(5)

# %%
# display no. of rows and columns
df.shape

# %%
# display data types
df.dtypes

# %%
# dsiplay information of the dataframe
df.info()

# %%
# summarize the dataframe
df.describe()

# %%
df.describe(include = 'all') # including string columns

# %%
# display all the column names
df.columns

# %%
# dsiplay  workclass column only  # select workclass from employee
df['workclass']

# %%
# display unique workclasses
df['workclass'].unique()

# %%
# display no of unique workclasses
df['workclass'].nunique()

# %%
# get the count of each distinct workclass
df['workclass'].value_counts()

# %%
# display n rows  only  based on indexing
#df.iloc[rows,columns]
df.iloc[10:14]

# %%
# display n rows and n columns only 
#df.iloc[rows,columns]
df.iloc[10:14 ,3:6]

# %%
# display n rows  only 
df.loc[10:14]

# %%
df.shape

# %%
df.drop_duplicates(inplace=True)

# %%
df.sort_values(by = 'age') # ascendig order

# %%
df.sort_values(by = 'age', ascending=False) # descending oder

# %%
# conditions  # sql : selectr  * from employee where workclass = "Private"
cond = df['workclass'] == " Private"
cond
df[cond]

# or - writing in single line
#df[ df['workclass'] == " Private"]

# %%
# multiple conditions

cond1 = df['workclass'] == " Private"
cond2 = df['age'] == 38

df[cond1 & cond2]

# %%
output =  df.sample(frac=0.01)
output

# %%
df['workclass']
# Out:
# 0                State-gov
# 1         Self-emp-not-inc
# 2                  Private
# 3                  Private
# 4                  Private
#                ...
# 32556              Private
# 32557              Private
# 32558              Private
# 32559              Private
# 32560         Self-emp-inc
# Name: workclass, Length: 32561, dtype: str

# %%
#subset
df[ ['workclass','age','education'] ]
# Out:
#                workclass  age    education
# 0              State-gov   39    Bachelors
# 1       Self-emp-not-inc   50    Bachelors
# 2                Private   38      HS-grad
# 3                Private   53         11th
# 4                Private   28    Bachelors
# ...                  ...  ...          ...
# 32556            Private   27   Assoc-acdm
# 32557            Private   40      HS-grad
# 32558            Private   58      HS-grad
# 32559            Private   22      HS-grad
# 32560       Self-emp-inc   52      HS-grad
#
# [32561 rows x 3 columns]

# %%
# %pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.3 MB 6.4 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.3 MB 6.7 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.3 MB 7.0 MB/s eta 0:00:01
#    --------------------------- ------------ 5.8/8.3 MB 7.2 MB/s eta 0:00:01
#    --------------------------------- ------ 7.1/8.3 MB 7.1 MB/s eta 0:00:01
#    -------------------------------------- - 8.1/8.3 MB 7.2 MB/s eta 0:00:01
#    -------------------------------------- - 8.1/8.3 MB 7.2 MB/s eta 0:00:01
#    -------------------------------------- - 8.1/8.3 MB 7.2 MB/s eta 0:00:01
#    -------------------------------------- - 8.1/8.3 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 4.4 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB 3.7 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt

labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
plt.savefig("output.jpg")
